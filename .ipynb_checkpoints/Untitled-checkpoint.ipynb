# %%
import matplotlib.pyplot as plt

from daily_forecast import import_data, create_forecast_dates, map_calendar, map_holidays, map_snaps
from daily_forecast import rank_products, filter_product, unpivot_weeks
from daily_forecast import join_snaps, join_dates, tag_train_eval, join_holidays, join_prices, include_diff_dates
from daily_forecast import boxcox_transform
from daily_forecast import select_variables, transform_dummies, train_eval_split, train_test_split, extract_X_y 
from daily_forecast import standardize_X, train_model, predict_model

# %%
df_raw, calendar, price = import_data()

# %%
df_raw = create_forecast_dates(df_raw)

# %%
mapping_calendar = map_calendar(calendar)
holidays = map_holidays(calendar)
snaps = map_snaps(calendar)

# %%
sorted_products = rank_products(df_raw)
id = sorted_products.index[1]

# %%
df = filter_product(df_raw, id)

# %%
df = unpivot_weeks(df)

# %%
df = join_snaps(df, snaps)

# %%
df = join_dates(df, mapping_calendar)

# %%
df = tag_train_eval(df)

# %%
df = join_holidays(df, holidays)

# %%
df = join_prices(df, price)

# %%
df = include_diff_dates(df)

# %%
df, boxcox_lambda = boxcox_transform(df)

# %%
df, item = select_variables(df)

# %%
df = transform_dummies(df)

# %%
df.head()
# Out:
#                 value  snap  sell_price  dt  dt2  eval_set  weekday_1_Tue  \
# date
# 2011-01-29  83.159622     0        1.48   0    0     False              0
# 2011-01-30  72.570208     0        1.48   1    1     False              0
# 2011-01-31  41.141638     0        1.48   2    4     False              0
# 2011-02-01  48.663496     1        1.48   3    9     False              1
# 2011-02-02  44.491932     0        1.48   4   16     False              0
#
#             weekday_2_Wed  weekday_3_Thu  weekday_4_Fri  ...  \
# date                                                     ...
# 2011-01-29              0              0              0  ...
# 2011-01-30              0              0              0  ...
# 2011-01-31              0              0              0  ...
# 2011-02-01              0              0              0  ...
# 2011-02-02              1              0              0  ...
#
#             holiday_IndependenceDay  holiday_LaborDay  holiday_Mother's day  \
# date
# 2011-01-29                        0                 0                     0
# 2011-01-30                        0                 0                     0
# 2011-01-31                        0                 0                     0
# 2011-02-01                        0                 0                     0
# 2011-02-02                        0                 0                     0
#
#             holiday_NBAFinalsEnd  holiday_NBAFinalsStart  holiday_NewYear  \
# date
# 2011-01-29                     0                       0                0
# 2011-01-30                     0                       0                0
# 2011-01-31                     0                       0                0
# 2011-02-01                     0                       0                0
# 2011-02-02                     0                       0                0
#
#             holiday_Ramadan starts  holiday_SuperBowl  holiday_Thanksgiving  \
# date
# 2011-01-29                       0                  0                     0
# 2011-01-30                       0                  0                     0
# 2011-01-31                       0                  0                     0
# 2011-02-01                       0                  0                     0
# 2011-02-02                       0                  0                     0
#
#             holiday_ValentinesDay
# date
# 2011-01-29                      0
# 2011-01-30                      0
# 2011-01-31                      0
# 2011-02-01                      0
# 2011-02-02                      0
#
# [5 rows x 40 columns]

# %%
df_training, df_eval= train_eval_split(df)

# %%
df_train, df_test = train_test_split(df_training)

# %%
X_train, y_train = extract_X_y(df_train)
X_test, y_test = extract_X_y(df_test)
X_eval, y_eval = extract_X_y(df_eval)

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_train, label='train')
plt.plot(y_test, label='test')
plt.plot(y_eval, label='eval')
plt.legend()
plt.show()

# %%
X_train, X_test, X_eval = standardize_X(X_train, X_test, X_eval)

# %%
model = train_model(X_train, y_train)

# %%
y_test['pred'] = predict_model(model, X_test)

# %%
y_train['pred'] = predict_model(model, X_train)

# %%
plt.plot(y_train['value'])
plt.plot(y_train['pred'])

# %%
y_train
# Out:
#                  value        pred
# date
# 2011-01-29   83.159622   93.760950
# 2011-01-30   72.570208   89.355147
# 2011-01-31   41.141638   60.460994
# 2011-02-01   48.663496   70.938079
# 2011-02-02   44.491932   67.817010
# 2011-02-03   51.988747   75.243546
# 2011-02-04   54.476170   83.346073
# 2011-02-05   81.534801  106.756700
# 2011-02-06   80.721823   92.529680
# 2011-02-07   79.094712   73.456101
# 2011-02-08   38.620652   67.000842
# 2011-02-09   51.988747   72.063094
# 2011-02-10   45.327647   71.305666
# 2011-02-11   77.466032   87.591515
# 2011-02-12  111.377092  106.909999
# 2011-02-13   91.262020  102.503554
# 2011-02-14   43.655490   77.928054
# 2011-02-15   83.159622   71.244998
# 2011-02-16   51.158386   68.123287
# 2011-02-17   48.663496   71.457358
# 2011-02-18   73.387225   83.651065
# 2011-02-19   82.347399  102.969228
# 2011-02-20   88.025284   98.562461
# 2011-02-21   50.327399   69.667344
# 2011-02-22   76.651092   67.303263
# 2011-02-23   66.018103   68.273052
# 2011-02-24   57.784564   71.606802
# 2011-02-25   73.387225   83.800187
# 2011-02-26  104.960451  103.118029
# 2011-02-27   83.159622   98.710941
# ...                ...         ...
# 2015-03-09   70.116550   58.225551
# 2015-03-10   56.131503   51.701858
# 2015-03-11   60.260048   56.695678
# 2015-03-12   67.658869   59.961638
# 2015-03-13   69.297778   72.087232
# 2015-03-14   93.686030   87.245462
# 2015-03-15  100.135899   86.862405
# 2015-03-16   65.197008   53.807354
# 2015-03-17   70.934875   51.375162
# 2015-03-18   59.435424   52.276838
# 2015-03-19   61.084147   55.542477
# 2015-03-20   89.644337   67.667751
# 2015-03-21   73.387225   86.917480
# 2015-03-22   77.466032   82.442280
# 2015-03-23   63.553361   53.478730
# 2015-03-24    0.982688   51.046217
# 2015-03-25   94.493376   51.947572
# 2015-03-26   51.988747   55.212889
# 2015-03-27   51.988747   67.337842
# 2015-03-28  104.960451   86.587250
# 2015-03-29   81.534801   82.111729
# 2015-03-30   61.084147   53.147857
# 2015-03-31   47.830558   50.715022
# 2015-04-01   77.466032   51.593653
# 2015-04-02   66.838722   50.766827
# 2015-04-03  105.763518   66.983280
# 2015-04-04   93.686030   82.140545
# 2015-04-05   95.300399   98.429801
# 2015-04-06   64.375430   52.792331
# 2015-04-07   59.435424   50.359175
#
# [1530 rows x 2 columns]
